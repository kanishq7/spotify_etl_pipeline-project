# %%
! pip install spotipy
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from platform import python_version
python_version()
# Out:
# '3.9.12'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#for authentication
client_credentials_manager=SpotifyClientCredentials(client_id='c1e439f202794f0a9c5d97624960ff7c',client_secret='638a49f9dbe04ffdb09821f496c8cd32')

# %%
#for authorisation

sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link='https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF' #top 50 global songs

# %%
playlists=sp.user_playlists('spotify')

# %%
playlist_URI=playlist_link.split("/")[-1]  #extracting the playlist id

# %%
playlist_URI
# Out:
# '37i9dQZEVXbMDoHDwVN2tF'

# %%
data= sp.playlist_tracks(playlist_URI)

# %%
data["items"]
# Out:
# [{'added_at': '2023-05-21T09:47:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#       'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#       'id': '0XeEobZplHxzM9QzFQWLiR',
#       'name': 'Eslabon Armado',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
data["items"][0]['track']['album']['id']
# Out:
# '5aDEezKnOqyQo0qvTFhpkM'

# %%
data["items"][0]['track']['album']['name']
# Out:
# 'DESVELADO'

# %%
data["items"][0]['track']['album']['release_date']
# Out:
# '2023-04-28'

# %%
data["items"][0]['track']['album']['total_tracks']
# Out:
# 16

# %%
data["items"][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'}

# %%
album_list=[]
for row in data["items"]:
    album_id= row['track']['album']['id']
    album_url=row['track']['album']['external_urls']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_element={'album':album_id,'url':album_url,'name':album_name,'release_date':album_release_date,
                  'total_tracks':album_total_tracks}
    
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album': '5aDEezKnOqyQo0qvTFhpkM',
#   'url': {'spotify': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#   'name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16},
#  {'album': '5gCcb5fsSb6w5K8SyJrgtB',
#   'url': {'spotify': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'},
#   'name': 'WHERE SHE GOES',
#   'release_date': '2023-05-18',
#   'total_tracks': 1},
#  {'album': '7aGzSSUD8S6IhPCsZSiuMT',
#   'url': {'spotify': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'},
#   'name': 'un x100to',
#   'release_date': '2023-04-17',
#   'total_tracks': 1},
#  {'album': '6aBVGuOUEuX18rHxyDWbti',
#   'url': {'spotify': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#   'name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
#   'total_tracks': 2},
#  {'album': '5letLUZIFsQikJYShfGNs4',
#   'url': {'spotify': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
#   'name': 'The Beginning: Cupid',
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#   'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#   'id': '6XkjpgcEsYab502Vr1bBeW',
#   'name': 'Grupo Frontera',
#   'type': 'artist',
#   'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#   'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#   'id': '4q3ewBCX7sLwd24euuV69X',
#   'name': 'Bad Bunny',
#   'type': 'artist',
#   'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}]

# %%
artist_list= []
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict={'artist_id': artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'external_url': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'external_url': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '3qQbCzHBycnDpGskqOWY0E',
#   'song_name': 'Ella Baila Sola',
#   'duration_ms': 165671,
#   'url': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E',
#   'popularity': 90,
#   'song_added': '2023-05-21T09:47:30Z',
#   'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'artist_id': '0XeEobZplHxzM9QzFQWLiR'},
#  {'song_id': '7ro0hRteUMfnOioTFI5TG1',
#   'song_name': 'WHERE SHE GOES',
#   'duration_ms': 231704,
#   'url': 'https://open.spotify.com/track/7ro0hRteUMfnOioTFI5TG1',
#   'popularity': 82,
#   'song_added': '2023-05-21T09:47:30Z',
#   'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '6pD0ufEQq0xdHSsRbg9LBK',
#   'song_name': 'un x100to',
#   'duration_ms': 194563,
#   'url': 'https://open.spotify.com/track/6pD0ufEQq0xdHSsRbg9LBK',
#   'popularity': 100,
#   'song_added': '2023-05-21T09:47:30Z',
#   'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'artist_id': '6XkjpgcEsYab502Vr1bBeW'},
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                     album                                                url  \
# 0  5aDEezKnOqyQo0qvTFhpkM  {'spotify': 'https://open.spotify.com/album/5a...
# 1  5gCcb5fsSb6w5K8SyJrgtB  {'spotify': 'https://open.spotify.com/album/5g...
# 2  7aGzSSUD8S6IhPCsZSiuMT  {'spotify': 'https://open.spotify.com/album/7a...
# 3  6aBVGuOUEuX18rHxyDWbti  {'spotify': 'https://open.spotify.com/album/6a...
# 4  5letLUZIFsQikJYShfGNs4  {'spotify': 'https://open.spotify.com/album/5l...
#
#                    name release_date  total_tracks
# 0             DESVELADO   2023-04-28            16
# 1        WHERE SHE GOES   2023-05-18             1
# 2             un x100to   2023-04-17             1
# 3       La Bebe (Remix)   2023-03-17             2
# 4  The Beginning: Cupid   2023-02-24             3

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album         50 non-null     object
#  1   url           50 non-null     object
#  2   name          50 non-null     object
#  3   release_date  50 non-null     object
#  4   total_tracks  50 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album'])

# %%
album_df
# Out:
#                      album                                                url  \
# 0   5aDEezKnOqyQo0qvTFhpkM  {'spotify': 'https://open.spotify.com/album/5a...
# 1   5gCcb5fsSb6w5K8SyJrgtB  {'spotify': 'https://open.spotify.com/album/5g...
# 2   7aGzSSUD8S6IhPCsZSiuMT  {'spotify': 'https://open.spotify.com/album/7a...
# 3   6aBVGuOUEuX18rHxyDWbti  {'spotify': 'https://open.spotify.com/album/6a...
# 4   5letLUZIFsQikJYShfGNs4  {'spotify': 'https://open.spotify.com/album/5l...
# 5   0HiZ8fNXwJOQcrf5iflrdz  {'spotify': 'https://open.spotify.com/album/0H...
# 6   1nrVofqDRs7cpWXJ49qTnP  {'spotify': 'https://open.spotify.com/album/1n...
# 7   6NcI39WPu4kY6Tul11nhSv  {'spotify': 'https://open.spotify.com/album/6N...
# 8   5r36AJ6VOJtp00oxSkBZ5h  {'spotify': 'https://open.spotify.com/album/5r...
# 9   4ZQmQzeicvUGkLxFTI2Dvd  {'spotify': 'https://open.spotify.com/album/4Z...
# 10  4kS7bSuU0Jm9LYMosFU2x5  {'spotify': 'https://open.spotify.com/album/4k...
# ...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 1  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 2  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 3  6XkjpgcEsYab502Vr1bBeW  Grupo Frontera
# 4  4q3ewBCX7sLwd24euuV69X       Bad Bunny
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 1  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 2  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 3  https://api.spotify.com/v1/artists/6XkjpgcEsYa...
# 4  https://api.spotify.com/v1/artists/4q3ewBCX7sL...

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.head()
# Out:
#                     album                                                url  \
# 0  5aDEezKnOqyQo0qvTFhpkM  {'spotify': 'https://open.spotify.com/album/5a...
# 1  5gCcb5fsSb6w5K8SyJrgtB  {'spotify': 'https://open.spotify.com/album/5g...
# 2  7aGzSSUD8S6IhPCsZSiuMT  {'spotify': 'https://open.spotify.com/album/7a...
# 3  6aBVGuOUEuX18rHxyDWbti  {'spotify': 'https://open.spotify.com/album/6a...
# 4  5letLUZIFsQikJYShfGNs4  {'spotify': 'https://open.spotify.com/album/5l...
#
#                    name release_date  total_tracks
# 0             DESVELADO   2023-04-28            16
# 1        WHERE SHE GOES   2023-05-18             1
# 2             un x100to   2023-04-17             1
# 3       La Bebe (Remix)   2023-03-17             2
# 4  The Beginning: Cupid   2023-02-24             3

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  3qQbCzHBycnDpGskqOWY0E    Ella Baila Sola       165671
# 1  7ro0hRteUMfnOioTFI5TG1     WHERE SHE GOES       231704
# 2  6pD0ufEQq0xdHSsRbg9LBK          un x100to       194563
# 3  2UW7JaomAMuX9pZrjVpHAU    La Bebe - Remix       234352
# 4  7FbrGaHYVDmfr7KoLIZnQ7  Cupid - Twin Ver.       174253
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...          90
# 1  https://open.spotify.com/track/7ro0hRteUMfnOio...          82
# 2  https://open.spotify.com/track/6pD0ufEQq0xdHSs...         100
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...          99
# 4  https://open.spotify.com/track/7FbrGaHYVDmfr7K...          98
#
#              song_added                album_id               artist_id
# 0  2023-05-21T09:47:30Z  5aDEezKnOqyQo0qvTFhpkM  0XeEobZplHxzM9QzFQWLiR
# 1  2023-05-21T09:47:30Z  5gCcb5fsSb6w5K8SyJrgtB  4q3ewBCX7sLwd24euuV69X
# ...

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  3qQbCzHBycnDpGskqOWY0E    Ella Baila Sola       165671
# 1  7ro0hRteUMfnOioTFI5TG1     WHERE SHE GOES       231704
# 2  6pD0ufEQq0xdHSsRbg9LBK          un x100to       194563
# 3  2UW7JaomAMuX9pZrjVpHAU    La Bebe - Remix       234352
# 4  7FbrGaHYVDmfr7KoLIZnQ7  Cupid - Twin Ver.       174253
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...          90
# 1  https://open.spotify.com/track/7ro0hRteUMfnOio...          82
# 2  https://open.spotify.com/track/6pD0ufEQq0xdHSs...         100
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...          99
# 4  https://open.spotify.com/track/7FbrGaHYVDmfr7K...          98
#
#                  song_added                album_id               artist_id
# 0 2023-05-21 09:47:30+00:00  5aDEezKnOqyQo0qvTFhpkM  0XeEobZplHxzM9QzFQWLiR
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
